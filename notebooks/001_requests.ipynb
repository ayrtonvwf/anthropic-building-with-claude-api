# %%
import sys
# !{sys.executable} -m ensurepip --upgrade
# Out:
# Looking in links: /var/folders/dd/tpdzgsps29l6xqx8hm7z2_rr0000gp/T/tmptax7mggi
# Processing /var/folders/dd/tpdzgsps29l6xqx8hm7z2_rr0000gp/T/tmptax7mggi/pip-25.1.1-py3-none-any.whl
# Installing collected packages: pip
# Successfully installed pip-25.1.1

# %%
# Install dependencies
# %pip install anthropic python-dotenv

# %%
# Load env vars

from dotenv import load_dotenv
load_dotenv()

# %%
# Create an API client

from anthropic import Anthropic

client = Anthropic()
model = "claude-haiku-4-5"

# %%
from anthropic.types import MessageParam

def add_user_message(messages: list[MessageParam], text: str):
    user_message: MessageParam = {"role": "user", "content": text}
    messages.append(user_message)

def add_assistant_message(messages: list[MessageParam], text: str):
    assistant_message: MessageParam = {"role": "assistant", "content": text }
    messages.append(assistant_message)

from anthropic.types import TextBlock, Message

def get_message_text(message: Message):
    return next(
        (block.text for block in message.content if isinstance(block, TextBlock)),
        "" # empty string if none
    )

# %%
# Make a request

message = client.messages.create(
    model=model,
    max_tokens=1000,
    messages=[
        {
            "role": "user",
            "content": "What is quantum computing? Answer in one sentence"
        }
    ]
)

# %%
# Show message result
get_message_text(message)
# Out:
# 'Quantum computing is a type of computing that uses quantum bits (qubits) that can exist in multiple states simultaneously, allowing quantum computers to solve certain complex problems much faster than classical computers.'
