# %%
import sys
# !{sys.executable} -m ensurepip --upgrade
# Out:
# Looking in links: /var/folders/dd/tpdzgsps29l6xqx8hm7z2_rr0000gp/T/tmptqc2nd0r
# Requirement already satisfied: pip in /Users/weback/projects/ayrton/anthropic-building-with-claude-api/.venv/lib/python3.13/site-packages (25.1.1)

# %%
# Install dependencies
# %pip install anthropic python-dotenv
# Out:
# Requirement already satisfied: anthropic in /Users/weback/projects/ayrton/anthropic-building-with-claude-api/.venv/lib/python3.13/site-packages (0.116.0)
# Requirement already satisfied: python-dotenv in /Users/weback/projects/ayrton/anthropic-building-with-claude-api/.venv/lib/python3.13/site-packages (1.2.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/weback/projects/ayrton/anthropic-building-with-claude-api/.venv/lib/python3.13/site-packages (from anthropic) (4.14.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/weback/projects/ayrton/anthropic-building-with-claude-api/.venv/lib/python3.13/site-packages (from anthropic) (1.9.0)
# Requirement already satisfied: docstring-parser<1,>=0.15 in /Users/weback/projects/ayrton/anthropic-building-with-claude-api/.venv/lib/python3.13/site-packages (from anthropic) (0.18.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in /Users/weback/projects/ayrton/anthropic-building-with-claude-api/.venv/lib/python3.13/site-packages (from anthropic) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/weback/projects/ayrton/anthropic-building-with-claude-api/.venv/lib/python3.13/site-packages (from anthropic) (0.16.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /Users/weback/projects/ayrton/anthropic-building-with-claude-api/.venv/lib/python3.13/site-packages (from anthropic) (2.13.4)
# Requirement already satisfied: sniffio in /Users/weback/projects/ayrton/anthropic-building-with-claude-api/.venv/lib/python3.13/site-packages (from anthropic) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.14 in /Users/weback/projects/ayrton/anthropic-building-with-claude-api/.venv/lib/python3.13/site-packages (from anthropic) (4.16.0)
# Requirement already satisfied: idna>=2.8 in /Users/weback/projects/ayrton/anthropic-building-with-claude-api/.venv/lib/python3.13/site-packages (from anyio<5,>=3.5.0->anthropic) (3.18)
# Requirement already satisfied: certifi in /Users/weback/projects/ayrton/anthropic-building-with-claude-api/.venv/lib/python3.13/site-packages (from httpx<1,>=0.25.0->anthropic) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in /Users/weback/projects/ayrton/anthropic-building-with-claude-api/.venv/lib/python3.13/site-packages (from httpx<1,>=0.25.0->anthropic) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/weback/projects/ayrton/anthropic-building-with-claude-api/.venv/lib/python3.13/site-packages (from httpcore==1.*->httpx<1,>=0.25.0->anthropic) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/weback/projects/ayrton/anthropic-building-with-claude-api/.venv/lib/python3.13/site-packages (from pydantic<3,>=1.9.0->anthropic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /Users/weback/projects/ayrton/anthropic-building-with-claude-api/.venv/lib/python3.13/site-packages (from pydantic<3,>=1.9.0->anthropic) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/weback/projects/ayrton/anthropic-building-with-claude-api/.venv/lib/python3.13/site-packages (from pydantic<3,>=1.9.0->anthropic) (0.4.2)
#
# [notice] A new release of pip is available: 25.1.1 -> 26.1.2
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# Load env vars

from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
# Create an API client

from anthropic import Anthropic

client = Anthropic()
model = "claude-haiku-4-5"

# %%
from anthropic.types import MessageParam
from collections.abc import Iterable

def add_user_message(messages: list[MessageParam], text: str):
    user_message: MessageParam = {"role": "user", "content": text}
    messages.append(user_message)

def add_assistant_message(messages: list[MessageParam], text: str):
    assistant_message: MessageParam = {"role": "assistant", "content": text }
    messages.append(assistant_message)

from anthropic.types import TextBlock, Message

def get_message_text(message: Message):
    return next(
        (block.text for block in message.content if isinstance(block, TextBlock)),
        "" # empty string if none
    )

def chat(messages: Iterable[MessageParam]):
    message = client.messages.create(
        model=model,
        max_tokens=1000,
        messages=messages
    )
    return get_message_text(message)

# %%
# Make a starting list of messages

messages = []

# Add in the initial user question

add_user_message(messages, "Define quantum computing in one sentence")

# Pass the list of messages into 'chat' to get an answer

first_answer = chat(messages)

# Output the first answer to debug

print(first_answer)

# Take the answer and add it as an assistant message into our list

add_assistant_message(messages, first_answer)

# Add in the user's follow-up question

add_user_message(messages, "Write another sentence")

# Call chat again with the list of messages to get a final answer

second_answer = chat(messages)

# Output the second answer to debug

print(second_answer)
# Out:
# Quantum computing is a type of computing that uses quantum bits (qubits) to perform calculations by exploiting quantum mechanical properties like superposition and entanglement, potentially solving certain problems much faster than classical computers.
# Unlike classical computers that process information as either 0 or 1, qubits can exist in a superposition of both states simultaneously, allowing quantum computers to explore many possible solutions in parallel.
